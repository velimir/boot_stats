# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns

sns.set()

# %%
df = pd.read_csv('stats.csv')
df['first_call'] = df['init'].notna()

# %%
ax = sns.boxplot(x=df[df['mode'] == 'interactive']['init'])

# %%
ax = sns.boxplot(x=df[df['mode'] == 'embedded']['init'])

# %%
ax = sns.boxplot(x="mode", y="init", data=df)

# %%
ax = sns.boxplot(x="mode", y="duration", hue="first_call", hue_order=[True, False], data=df)
